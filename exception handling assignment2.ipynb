# %% [markdown]
# #Q1 built in exceptions offer information about python related problems and custom exceptions will add information about project related problems. We use exception class while creating a custom Exception in order to inherit all the built in exceptions and using it with custom exception will expand the exception class. Exception class is the super class which means it has all the exceptions so inheriting it in custom exception will help to make a code better as we only create a custom exception when the Exception class don't raise errors because the result is acceptable by the system but not in real world. so when the built in exceptions cannot raise exception, custom class is created which inherits exception class as built in exceptions can also be raised while creating the custom exception

# %%
#Q2
import inspect as ipt
def tree_class(cls, ind = 0):
    print('-'*ind, cls.__name__)
    for k in cls.__subclasses__():
        tree_class(k, ind+3)
        print("the hierarchy for inbuilt exceptions is: ")
ipt.getclasstree(ipt.getmro(BaseException))
tree_class(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# the hierarchy for inbuilt exceptions is:
# --------- MultipartConversionError
# the hierarchy for inbuilt exceptions is:
# the hierarchy for inbuilt exceptions is:
# ------ StopAsyncIteration
# the hierarchy for inbuilt exceptions is:
# ------ StopIteration
# the hierarchy for inbuilt exceptions is:
# ------ ImportError
# --------- ModuleNotFoundError
# the hierarchy for inbuilt exceptions is:
# --------- ZipImportError
# the hierarchy for inbuilt exceptions is:
# the hierarchy for inbuilt exceptions is:
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# the hierarchy for inbuilt exceptions is:
# ------------ ConnectionAbortedError
# the hierarchy for inbuilt exceptions is:
# ------------ ConnectionRefusedError
# the hierarchy for inbuilt exceptions is:
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# the hierarchy for inbuilt exceptions is:
# ...

# %% [markdown]
# #Q3 aithmeticerror occurs during numeric calculations.
# two types of aithmeticerror are;
# ZeroDivisionError and
# OverflowError and FloatingPointError

# %%
#example of ZeroDivisionError
try:
    a = 4/0
    print(a)
except ArithmeticError as e:
    print("you have made an arithmetic error", e)
# Out:
# you have made an arithmetic error division by zero

# %%
#example of overflowError
j = 5
try:
    for i in range(1,1000):
        j = j**i
except ArithmeticError as e:
    print("ArithmericError", e)

# %% [markdown]
# #Q4
# The LookupError exception in python forms the base classs for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.
# we can use LookupError exception class to handle both IndexError and KeyError exception classes

# %%
#example of IndexError
x = [2,3,4,5,6]
try:
    print(x[8])
except LookupError as e:
    print("LookupError:", e)
# Out:
# LookupError: list index out of range

# %%
#example of KeyError
student_info = {'name': "Ironman", "age": 19 , "id_number": 456}
user_input= input("what do you want to learn about student?")
try:
    print(f'{user_input} is {student_info[user_input]}')
except LookupError as e:
    print(f'{e}, {e.__class__}')
# Out:
# what do you want to learn about student? email
# 'email', <class 'KeyError'>

# %% [markdown]
# #Q5 The import error is raised when an import statement has trouble successfully importing the specified module. typically, such a problem is due to invalid or incorrect path, which will raise a ModuleNotFoundError.
# It's raised specifically when the module cannot be found at all. Other problems can occur after the file is found, but during the actual process of loading the file or defining the function: those would raise ImportError.
# There's probably not much you can do about a ModuleNotFoundError; you can either ignore it and not use the module you tried to import later in the code, or exit and fix your environment so that the module will be found.

# %% [markdown]
# #Q6
# 1. always use a specific error
# 2. always print proper message
# 3. always try to log your error
# 4. avoid writing multiple exception handling
# 5. document all the errors
# 6. clean all the resources
